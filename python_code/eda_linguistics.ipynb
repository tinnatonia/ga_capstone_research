# %%
import pandas as pd
import matplotlib as plt
import numpy as np
from ydata_profiling import ProfileReport
from bs4 import BeautifulSoup as soup
import requests as rq

# %%
gram=pd.read_csv(filepath_or_buffer='C:\\Users\DAIR Julia\Desktop\linguistics_capstone\data\grambank\cldf\languages.csv')
gram.drop(['ID', 'ISO639P3code', 'provenance', 'Language_level_ID'], inplace=True, axis=1)

glotto=pd.read_csv(filepath_or_buffer='C:/Users/DAIR Julia/Desktop/linguistics_capstone/data/glottolog_cldf/cldf/languages.csv')
glotto.drop(['ID','Closest_ISO369P3code', 'Language_ID', 'First_Year_Of_Documentation', 'Last_Year_Of_Documentation', 
             'ISO639P3code'], inplace=True, axis=1)

values_df=pd.read_csv(filepath_or_buffer='C:/Users/DAIR Julia/Desktop/linguistics_capstone/data/glottolog_cldf/cldf/values.csv')

codes=pd.read_csv(filepath_or_buffer='C:\\Users\DAIR Julia\Desktop\linguistics_capstone\data\glottolog_cldf\cldf\codes.csv')

# %%
gram.columns

# %%
gram.head()

# %%
ProfileReport(gram)

# %%
glotto[glotto['Name'] == 'Abadi']

# %%
#Code to view Glotto fields with high null content:

#glotto[pd.isnull(glotto['Countries'])].head(50)
glotto[pd.isnull(glotto['Macroarea'])].head(50)

# %%
#https:\\en.wal.unesco.org\discover\languages?text=&sort_by=title&page=4

#scrape to get # speakers, and endangered status

page_url='https:\\en.wal.unesco.org\discover\languages?text=&sort_by=title&page=1'
wal_soup = soup(rq.get(page_url).text)


#<a href="https:\\en.wal.unesco.org\lcanguages\akpa" hreflang="en">Akpa<\a>

# %%
gram.head()
# Out:
#            Name  Macroarea  Latitude  Longitude Glottocode     Family_name  \
# 0         Abadi  Papunesia  -9.03389  146.99200   abad1241    Austronesian
# 1       Mungbam     Africa   6.58050   10.22670   abar1238  Atlantic-Congo
# 2          Abau  Papunesia  -3.97222  141.32400   abau1245           Sepik
# 3           Abé     Africa   5.59682   -4.38497   abee1242  Atlantic-Congo
# 4  Abenlen Ayta  Papunesia  15.41310  120.20000   aben1249    Austronesian
#
#   Family_level_ID     level  \
# 0        aust1307  language
# 1        atla1278  language
# 2        sepi1257  language
# 3        atla1278  language
# 4        aust1307  language
#
#                                                                                      lineage
# 0  aust1307/mala1545/cent2237/east2712/ocea1241/west2818/papu1253/peri1258/cent2070/west2850
# 1                                      atla1278/volt1241/benu1247/bant1294/sout3152/yemn1234
# 2                                                                                   sepi1257
# 3                                               atla1278/volt1241/kwav1236/nyoa1234/agne1238
# 4                                               aust1307/mala1545/cent2080/samb1319/abel1234

# %%
glotto.head()
# Out:
#               Name      Macroarea   Latitude   Longitude Glottocode Countries  \
# 0           Fulniô  South America  -9.025910  -37.140200   fuln1247        BR
# 1              Dem      Papunesia  -3.721830  137.632000   demm1245        ID
# 2       Mixe-Zoque            NaN  16.991902  -94.207907   mixe1284       NaN
# 3             Mure  South America -13.636709  -62.202091   mure1235        BO
# 4  North Halmahera            NaN   0.772624  127.656778   nort2923       NaN
#
#   Family_ID
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
pd.set_option('max_colwidth', 300)
values_df.head()

#need to pull from glotto join values, using Language_ID = glottocode, with 'Parameter_ID' like level, category, aes
# Out:
#                            ID Language_ID       Parameter_ID  \
# 0              fuln1247-level    fuln1247              level
# 1           fuln1247-category    fuln1247           category
# 2  fuln1247-subclassification    fuln1247  subclassification
# 3                fuln1247-aes    fuln1247                aes
# 4                fuln1247-med    fuln1247                med
#
#                                 Value                      Code_ID  \
# 0                            language               level-language
# 1                  Spoken_L1_Language  category-Spoken_L1_Language
# 2  (fuln1248:1,yate1241:1)fuln1247:1;                          NaN
# 3                                   3                 aes-shifting
# 4                                   0             med-long_grammar
#
#                                                                                                                                      Comment  \
# 0                                                                                                                                        NaN
# 1                                                                                                                                        NaN
# 2                                                                                                                                        NaN
# 3  Yaté (1642-fun) = Threatened (20 percent certain, based on the evidence available) [Crevels 2012](elcat:5ad6b7113e7c6615995bfd4cae2f3f8e)
# 4                                                                                                                                        NaN
#
#    Source  codeReference
# 0     NaN            NaN
# 1     NaN            NaN
# 2     NaN            NaN
# 3  569683            NaN
# 4  122653            NaN

# %%
codes.head(30)
# Out:
#                               ID Parameter_ID                 Name  \
# 0                   level-family        level               family
# 1                category-Family     category               Family
# 2         category-Pseudo_Family     category        Pseudo Family
# 3                 level-language        level             language
# 4              category-Language     category             Language
# 5       category-Pseudo_Language     category      Pseudo Language
# 6                  level-dialect        level              dialect
# 7               category-Dialect     category              Dialect
# 8        category-Pseudo_Dialect     category       Pseudo Dialect
# 9   category-Artificial_Language     category  Artificial Language
# 10          category-Bookkeeping     category          Bookkeeping
# 11       category-Mixed_Language     category       Mixed Language
# 12               category-Pidgin     category               Pidgin
# 13        category-Sign_Language     category        Sign Language
# 14      category-Speech_Register     category      Speech Register
# 15   category-Spoken_L1_Language     category   Spoken L1 Language
# 16           category-Unattested     category           Unattested
# 17       category-Unclassifiable     category       Unclassifiable
# 18            aes-not_endangered          aes       not endangered
# 19                aes-threatened          aes           threatened
# 20                  aes-shifting          aes             shifting
# 21                  aes-moribund          aes             moribund
# 22            aes-nearly_extinct          aes       nearly extinct
# 23                   aes-extinct          aes              extinct
# 24              med-long_grammar          med         long grammar
# 25                   med-grammar          med              grammar
# 26            med-grammar_sketch          med       grammar sketch
# 27         med-phonology_or_text          med       phonology/text
# 28          med-wordlist_or_less          med     Wordlist or less
#
#                                           Description  numerical_value
# 0   sub-grouping of languoids above the language l...              1.0
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3               defined by mutual non-intellegibility              2.0
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                 any variety which is not a language              3.0
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18             EGIDS: <=6a; UNESCO: safe; ElCat: safe              1.0
# 19   EGIDS: 6b; UNESCO: vulnerable; ElCat: vulnerable              2.0
# 20  EGIDS: 7; UNESCO: definitely endangered; ElCat...              3.0
# 21  EGIDS: 8a; UNESCO: severely endangered; ElCat:...              4.0
# 22  EGIDS: 8b; UNESCO: critically endangered; ElCa...              5.0
# 23        EGIDS: >=9; UNESCO: extinct; ElCat: extinct              6.0
# 24                   Grammar with more than 300 pages              0.0
# 25                   Grammar with less than 300 pages              1.0
# 26                                     Grammar sketch              2.0
# 27  New Testament, Text, Phonology, (typological) ...              3.0
# 28                                   Wordlist or less              4.0

# %%
values_df.shape

# %%
codes.shape

# %%
glotto.shape
# Out:
# (26669, 7)

# %%
gram.shape

# %%
values_df['Comment'][values_df['Comment'].notna()].head(40)
